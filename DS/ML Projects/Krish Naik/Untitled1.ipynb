# %%
# !pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\894524\.conda\envs\ml\lib\site-packages (1.56.0)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: six in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: lz4 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (3.1.3)
# Requirement already satisfied: requests in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.26.0)
# Requirement already satisfied: xlrd in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: ppscore in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (1.2.0)
# Requirement already satisfied: pandas in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (1.3.2)
# Requirement already satisfied: dash-colorscales in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: et-xmlfile in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: scipy in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: xarray in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.19.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (5.3.1)
# Requirement already satisfied: itsdangerous in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: dash>=1.5.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.0.0)
# Requirement already satisfied: kaleido in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: scikit-learn in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (0.24.2)
# Requirement already satisfied: strsimpy in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: Flask in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: dash-bootstrap-components in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.13.0)
# Requirement already satisfied: squarify in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: openpyxl in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (3.0.8)
# Requirement already satisfied: statsmodels in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.12.2)
# Requirement already satisfied: matplotlib in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (3.4.3)
# Requirement already satisfied: flask-ngrok in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: networkx in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (2.6.3)
# Requirement already satisfied: dash-daq in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: future>=0.14.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: Flask-Compress in c:\users\894524\.conda\envs\ml\lib\site-packages (from dtale) (1.10.1)
# Requirement already satisfied: numpy in c:\users\894524\appdata\roaming\python\python39\site-packages (from dtale) (1.21.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dash>=1.5.0->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dash>=1.5.0->dtale) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from dash>=1.5.0->dtale) (2.0.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from Flask->dtale) (3.0.1)
# Requirement already satisfied: click>=7.1.2 in c:\users\894524\.conda\envs\ml\lib\site-packages (from Flask->dtale) (8.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from Flask->dtale) (2.0.1)
# Requirement already satisfied: colorama in c:\users\894524\.conda\envs\ml\lib\site-packages (from click>=7.1.2->Flask->dtale) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from Jinja2>=3.0->Flask->dtale) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Requirement already satisfied: brotli in c:\users\894524\.conda\envs\ml\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib->dtale) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from matplotlib->dtale) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib->dtale) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\894524\.conda\envs\ml\lib\site-packages (from pandas->dtale) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\894524\appdata\roaming\python\python39\site-packages (from scikit-learn->dtale) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests->dtale) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests->dtale) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests->dtale) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: patsy>=0.5 in c:\users\894524\.conda\envs\ml\lib\site-packages (from statsmodels->dtale) (0.5.1)
# Requirement already satisfied: setuptools>=40.4 in c:\users\894524\.conda\envs\ml\lib\site-packages (from xarray->dtale) (58.0.4)

# %%
import dtale
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dtale\dash_application\charts.py:13: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\ProgramData\Anaconda3\lib\site-packages\dtale\dash_application\charts.py:14: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv ("titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LTIN309187:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.0.0-py2.py3-none-any.whl (248 kB)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from pandas-profiling) (0.1.0)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.0-cp39-cp39-win_amd64.whl (659 kB)
# Requirement already satisfied: joblib in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (1.0.1)
# Collecting tqdm>=4.48.2
#   Using cached tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from pandas-profiling) (2.26.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (3.0.1)
# Collecting PyYAML>=5.0.0
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (1.21.2)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (0.11.2)
# Collecting visions[type_image_path]==0.7.1
#   Using cached visions-0.7.1-py3-none-any.whl (102 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (3.4.3)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.8.2-cp39-cp39-win_amd64.whl (1.9 MB)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\894524\.conda\envs\ML\python.exe' 'C:\Users\894524\AppData\Local\Temp\pip-standalone-pip-_3zaonj5\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\894524\AppData\Local\Temp\pip-build-env-dfq63ilx\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'numpy==1.13.3; python_version=='"'"'2.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.13.3; python_version=='"'"'3.5'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'2.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.5'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"''
#        cwd: None
#   Complete output (640 lines):
#   Ignoring numpy: markers 'python_version == "2.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.5" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "2.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.5" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-58.0.4-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\894524\.conda\envs\ML\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-z74snxm0\\numpy_fb7c0041a60c4d359a385537a188861c\\setup.py'"'"'; __file__='"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-z74snxm0\\numpy_fb7c0041a60c4d359a385537a188861c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\894524\AppData\Local\Temp\pip-wheel-qasno3bt'
#          cwd: C:\Users\894524\AppData\Local\Temp\pip-install-z74snxm0\numpy_fb7c0041a60c4d359a385537a188861c\
#     Complete output (292 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: missingno>=0.4.2 in c:\users\894524\.conda\envs\ml\lib\site-packages (from pandas-profiling) (0.4.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\894524\appdata\roaming\python\python39\site-packages (from pandas-profiling) (1.3.2)
# Requirement already satisfied: multimethod==1.4 in c:\users\894524\.conda\envs\ml\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (1.4)
# Requirement already satisfied: networkx>=2.4 in c:\users\894524\.conda\envs\ml\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (21.2.0)
# Collecting bottleneck
#   Using cached Bottleneck-1.3.2.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached Bottleneck-1.3.1.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached Bottleneck-1.3.0.tar.gz (87 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached Bottleneck-1.2.1.tar.gz (105 kB)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in c:\users\894524\.conda\envs\ml\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (8.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\894524\appdata\roaming\python\python39\site-packages (from jinja2>=2.11.1->pandas-profiling) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\894524\AppData\Local\Temp\pip-install-z74snxm0\numpy_fb7c0041a60c4d359a385537a188861c\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     C:\Users\894524\AppData\Local\Temp\pip-install-z74snxm0\numpy_fb7c0041a60c4d359a385537a188861c\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\894524\AppData\Local\Temp\pip-install-z74snxm0\numpy_fb7c0041a60c4d359a385537a188861c\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\894524\\.conda\\envs\\ML\\lib', 'C:\\', 'C:\\Users\\894524\\.conda\\envs\\ML\\libs', 'C:\\ProgramData\\Anaconda3\\Library\\lib']
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\894524\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: six in c:\users\894524\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\894524\.conda\envs\ml\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.1)
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\894524\.conda\envs\ml\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: colorama in c:\users\894524\.conda\envs\ml\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\894524\.conda\envs\ml\lib\site-packages (from imagehash->visions[type_image_path]==0.7.1->pandas-profiling) (1.1.1)
# Building wheels for collected packages: bottleneck
#   Building wheel for bottleneck (setup.py): started
#   Building wheel for bottleneck (setup.py): finished with status 'error'
#   Running setup.py clean for bottleneck
# Failed to build bottleneck
# Installing collected packages: bottleneck, visions, typing-extensions, imagehash, tqdm, PyYAML, pydantic, phik, htmlmin, pandas-profiling
#     Running setup.py install for bottleneck: started
#     Running setup.py install for bottleneck: finished with status 'error'
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\ProgramData\Anaconda3\Library\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\ProgramData\Anaconda3\Library\lib
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\ProgramData\Anaconda3\Library\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\ProgramData\Anaconda3\Library\lib
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\894524\.conda\envs\ML\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\894524\.conda\envs\ML\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:
"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.14.5; python_version>='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'2.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.5'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version>='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\894524\.conda\envs\ML\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"'; __file__='"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\894524\AppData\Local\Temp\pip-wheel-tr7jzx9w'
#        cwd: C:\Users\894524\AppData\Local\Temp\pip-install-97d0i7vp\bottleneck_829ac695c81441abb8d87524ad5fce2e\
#   Complete output (36 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\bottleneck
#   copying bottleneck\version.py -> build\lib.win-amd64-3.9\bottleneck
#   copying bottleneck\__init__.py -> build\lib.win-amd64-3.9\bottleneck
#   creating build\lib.win-amd64-3.9\bottleneck\benchmark
#   copying bottleneck\benchmark\autotimeit.py -> build\lib.win-amd64-3.9\bottleneck\benchmark
#   copying bottleneck\benchmark\bench.py -> build\lib.win-amd64-3.9\bottleneck\benchmark
#   copying bottleneck\benchmark\bench_detailed.py -> build\lib.win-amd64-3.9\bottleneck\benchmark
#   copying bottleneck\benchmark\__init__.py -> build\lib.win-amd64-3.9\bottleneck\benchmark
#   creating build\lib.win-amd64-3.9\bottleneck\slow
#   copying bottleneck\slow\move.py -> build\lib.win-amd64-3.9\bottleneck\slow
#   copying bottleneck\slow\nonreduce.py -> build\lib.win-amd64-3.9\bottleneck\slow
#   copying bottleneck\slow\nonreduce_axis.py -> build\lib.win-amd64-3.9\bottleneck\slow
#   copying bottleneck\slow\reduce.py -> build\lib.win-amd64-3.9\bottleneck\slow
#   copying bottleneck\slow\__init__.py -> build\lib.win-amd64-3.9\bottleneck\slow
#   creating build\lib.win-amd64-3.9\bottleneck\src
#   copying bottleneck\src\template.py -> build\lib.win-amd64-3.9\bottleneck\src
#   copying bottleneck\src\__init__.py -> build\lib.win-amd64-3.9\bottleneck\src
#   creating build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\input_modifcation_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\list_input_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\move_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\nonreduce_axis_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\nonreduce_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\reduce_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\scalar_input_test.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\util.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\tests\__init__.py -> build\lib.win-amd64-3.9\bottleneck\tests
#   copying bottleneck\LICENSE -> build\lib.win-amd64-3.9\bottleneck
#   running build_ext
#   building 'bottleneck.reduce' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for bottleneck
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\894524\.conda\envs\ML\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"'; __file__='"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\894524\AppData\Local\Temp\pip-record-9de3yh3b\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\894524\.conda\envs\ML\Include\bottleneck'
#          cwd: C:\Users\894524\AppData\Local\Temp\pip-install-97d0i7vp\bottleneck_829ac695c81441abb8d87524ad5fce2e\
#     Complete output (6 lines):
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'bottleneck.reduce' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\894524\.conda\envs\ML\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"'; __file__='"'"'C:\\Users\\894524\\AppData\\Local\\Temp\\pip-install-97d0i7vp\\bottleneck_829ac695c81441abb8d87524ad5fce2e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\894524\AppData\Local\Temp\pip-record-9de3yh3b\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\894524\.conda\envs\ML\Include\bottleneck' Check the logs for full command output.

# %%
import seaborn as sns

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-e2a33329b6f0> in <module>
# ----> 1 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-e2a33329b6f0> in <module>
# ----> 1 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'
# Executing shutdown due to inactivity...
# 2021-09-14 19:18:32,813 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2021-09-14 19:18:36,868 - INFO     - Executing shutdown...

# %%
sensor=pd.read_excel("C:\\Documents\\DS\\TopMentee\\Tableau\\Sources\\vIZ wK 4\\Sensor Data Analysis.xlsx")
sensor
# Out:
#      Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0    2020-02-10  08:01:00                 0.2               214.0
# 1    2020-02-10  08:06:00               228.2               214.1
# 2    2020-02-10  08:11:00               228.3               203.6
# 3    2020-02-10  08:16:00               232.3               215.2
# 4    2020-02-10  08:21:00               231.7               203.6
# ...         ...       ...                 ...                 ...
# 1470 2020-02-15  10:38:00               227.7                 0.0
# 1471 2020-02-15  10:43:00               227.8                 0.0
# 1472 2020-02-15  10:48:00               231.0                 0.0
# 1473 2020-02-15  10:53:00               232.1                 0.0
# 1474 2020-02-15  10:58:00               232.1                 0.0
#
#       F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0                  0.125               216.3                 0.2
# 1                  0.000               216.8                 0.3
# 2                  0.125               217.0                 0.2
# 3                  0.125               216.2                 0.3
# 4                  0.000               216.3                 0.1
# ...                  ...                 ...                 ...
# 1470               0.125                 1.3               229.1
# 1471               0.250                 1.5               231.2
# 1472               0.125                 1.5               229.2
# 1473               0.125                 1.3               228.6
# 1474               0.125                 1.5               231.3
#
#       F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  ...  \
# 0                  217.8               223.6             237.875  ...
# 1                  218.0               214.2             237.875  ...
# 2                  217.2               211.6             237.750  ...
# 3                  215.6               212.1             237.625  ...
# 4                  218.0               209.6             237.750  ...
# ...                  ...                 ...                 ...  ...
# 1470                 1.2               214.5               1.750  ...
# 1471                 1.2               224.1               1.875  ...
# 1472                 1.3               213.8               1.875  ...
# 1473                 1.3               211.8               1.625  ...
# 1474                 1.3               212.5               1.625  ...
#
#       F13_rHydPump_400Bar  F13_rHydPump_200Bar  F13_rHydTank_Oil_Temp  \
# 0                   227.7                 95.6                   44.2
# 1                   227.0                 95.2                   45.9
# 2                   227.1                 95.1                   47.9
# 3                   227.3                 94.7                   49.6
# 4                   226.8                 94.7                   51.1
# ...                   ...                  ...                    ...
# 1470                226.7                 97.5                   51.4
# 1471                227.3                 97.8                   52.1
# 1472                226.8                 97.5                   51.3
# 1473                227.2                 97.8                   52.2
# 1474                226.7                 97.5                   51.3
#
#       F13_rAirFlowVelocity  F13_rMotorTemp  F14_rAirFlowVelocity  \
# 0                        0            36.2                 27.12
# 1                        0            38.2                 28.37
# 2                        0            39.9                  0.00
# 3                        0            41.4                  0.00
# 4                        0            42.7                  0.00
# ...                    ...             ...                   ...
# 1470                     0            50.2                  0.00
# 1471                     0            50.0                  0.00
# 1472                     0            50.2                  0.00
# 1473                     0            50.1                  0.00
# 1474                     0            50.3                  0.00
#
#       F14_rHydPump_200Bar  F14_rHydPump_400Bar  F14_rHydTank_Oil_Temp  \
# 0                    94.6                237.5                   52.0
# 1                    94.9                237.3                   51.8
# 2                     0.0                  0.3                   51.4
# 3                     0.0                  0.3                   51.3
# 4                     0.1                  0.3                   51.2
# ...                   ...                  ...                    ...
# 1470                  0.0                  0.1                   47.1
# 1471                  0.0                  0.0                   47.0
# 1472                  0.0                  0.3                   46.8
# 1473                  0.0                  0.2                   46.7
# 1474                  0.0                  0.2                   46.6
#
#       F14_rMotorTemp
# 0               46.3
# 1               46.4
# 2               47.0
# 3               52.9
# 4               53.0
# ...              ...
# 1470            37.0
# 1471            36.8
# 1472            36.6
# 1473            36.4
# 1474            36.1
#
# [1475 rows x 86 columns]

# %%
import dtale

# %%
dtale.show(sensor)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LTIN309187:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# C:\ProgramData\Anaconda3\lib\site-packages\dtale\describe.py:14: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.

# %%
import sweetviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-315aef12f63c> in <module>
# ----> 1 import sweetviz
#
# ModuleNotFoundError: No module named 'sweetviz'
# Executing shutdown due to inactivity...
# Executing shutdown due to inactivity...
# 2021-09-15 19:28:34,265 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# Executing shutdown...
# 2021-09-15 19:28:46,443 - INFO     - Executing shutdown...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.set_index('Cabin').loc['G6']
# Out:
#        PassengerId  Survived  Pclass  \
# Cabin
# G6              11         1       3
# G6             206         0       3
# G6             252         0       3
# G6             395         1       3
#
#                                                     Name     Sex   Age  SibSp  \
# Cabin
# G6                       Sandstrom, Miss. Marguerite Rut  female   4.0      1
# G6                            Strom, Miss. Telma Matilda  female   2.0      0
# G6            Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# G6     Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
#
#        Parch   Ticket     Fare Embarked
# Cabin
# G6         1  PP 9549  16.7000        S
# G6         1   347054  10.4625        S
# G6         1   347054  10.4625        S
# G6         2  PP 9549  16.7000        S

# %%
df[df['Cabin']=='C85']
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %% [markdown]
# df.style.highlight_null()

# %%
df['Cabin'].value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# C22 C26        3
# D              3
#               ..
# C106           1
# A20            1
# C30            1
# C7             1
# F38            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.style.bar()
# Out:
# <style  type="text/css" >
# #T_8a9de_row0_col0,#T_8a9de_row0_col1,#T_8a9de_row0_col7,#T_8a9de_row1_col2,#T_8a9de_row1_col7,#T_8a9de_row2_col6,#T_8a9de_row2_col7,#T_8a9de_row3_col2,#T_8a9de_row3_col7,#T_8a9de_row4_col1,#T_8a9de_row4_col6,#T_8a9de_row4_col7,#T_8a9de_row5_col1,#T_8a9de_row5_col6,#T_8a9de_row5_col7,#T_8a9de_row6_col1,#T_8a9de_row6_col2,#T_8a9de
9de_row56_col7,#T_8a9de_row57_col1,#T_8a9de_row57_col6,#T_8a9de_row57_col7,#T_8a9de_row59_col1,#T_8a9de_row60_col1,#T_8a9de_row60_col6,#T_8a9de_row60_col7,#T_8a9de_row61_col2,#T_8a9de_row61_col6,#T_8a9de_row61_col7,#T_8a9de_row62_col1,#T_8a9de_row62_col2,#T_8a9de_row62_col7,#T_8a9de_row63_col1,#T_8a9de_row64_col1,#T_8a9de_row64_col2,#T_8a9de_row64_col6,#T_8a9de_row64_col7,#T_8a9de_row66_col6,#T_8a9de_row66_col7,#T_8a9de_row67_col1,#T_8a9de_row67_col6,#T_8a9de_row67_col7,#T_8a9de_row69_col1,#T_8a9de_row69_col7,#T_8a9de_row70_col1,#T_8a9de_row70_col6,#T_8a9de_row70_col7,#T_8a9de_row71_col1,#T_8a9de_row72_col1,#T_8a9de_row72_col6,#T_8a9de_row72_col7,#T_8a9de_row73_col1,#T_8a9de_row73_col7,#T_8a9de_row74_col6,#T_8a9de_row74_col7,#T_8a9de_row75_col1,#T_8a9de_row75_col6,#T_8a9de_row75_col7,#T_8a9de_row76_col1,#T_8a9de_row76_col6,#T_8a9de_row76_col7,#T_8a9de_row77_col1,#T_8a9de_row77_col6,#T_8a9de_row77_col7,#T_8a9de_row78_col6,#T_8a9de_row79_col6,#T_8a9de_row79_col7,#T_8a9de_row80_col1,#T_8a9de_row80_col6,#T_8a9de_row80_col7,#T_8a9de_row81_col6,#T_8a9de_row81_col7,#T_8a9de_row82_col6,#T_8a9de_row82_col7,#T_8a9de_row83_col1,#T_8a9de_row83_col2,#T_8a9de_row83_col6,#T_8a9de_row83_col7,#T_8a9de_row84_col6,#T_8a9de_row84_col7,#T_8a9de_row85_col7,#T_8a9de_row86_col1,#T_8a9de_row87_col1,#T_8a9de_row87_col6,#T_8a9de_row87_col7,#T_8a9de_row88_col2,#T_8a9de_row89_col1,#T_8a9de_row89_col6,#T_8a9de_row89_col7,#T_8a9de_row90_col1,#T_8a9de_row90_col6,#T_8a9de_row90_col7,#T_8a9de_row91_col1,#T_8a9de_row91_col6,#T_8a9de_row91_col7,#T_8a9de_row92_col1,#T_8a9de_row92_col2,#T_8a9de_row92_col7,#T ...

# %%
df.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
#                                 2    \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
# Age                            26.0
# SibSp                             0
# Parch                             0
# Ticket             STON/O2. 3101282
# Fare                          7.925
# Cabin                           NaN
# Embarked                          S
#
#                                                       3    \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                  35.0
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
#                                   4                 5    \
# PassengerId                         5                 6
# Survived                            0                 0
# Pclass                              3                 3
# Name         Allen, Mr. William Henry  Moran, Mr. James
# Sex                              male              male
# Age                              35.0               NaN
# SibSp                               0                 0
# Parch                               0                 0
# Ticket                         373450            330877
# Fare                             8.05            8.4583
# Cabin                             NaN               NaN
# Embarked                            S                 Q
#
#                                  6                               7    \
# PassengerId                        7                               8
# Survived                           0                               0
# Pclass                             1                               3
# Name         McCarthy, Mr. Timothy J  Palsson, Master. Gosta Leonard
# Sex                             male                            male
# Age                             54.0                             2.0
# SibSp                              0                               3
# Parch                              0                               1
# Ticket                         17463                          349909
# Fare                         51.8625                          21.075
# Cabin                            E46                             NaN
# Embarked                           S                               S
#
#                                                            8    \
# PassengerId                                                  9
# Survived                                                     1
# Pclass                                                       3
# Name         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Sex                                                     female
# Age                                                       27.0
# SibSp                                                        0
# Parch                                                        2
# Ticket                                                  347742
# Fare                                                   11.1333
# Cabin                                                      NaN
# Embarked                                                     S
#
#                                              9    ...                 881  \
# PassengerId                                   10  ...                 882
# Survived                                       1  ...                   0
# Pclass                                         2  ...                   3
# Name         Nasser, Mrs. Nicholas (Adele Achem)  ...  Markun, Mr. Johann
# Sex                                       female  ...                male
# Age                                         14.0  ...                33.0
# SibSp                                          1  ...                   0
# Parch                                          0  ...                   0
# Ticket                                    237736  ...              349257
# Fare                                     30.0708  ...              7.8958
# Cabin                                        NaN  ...                 NaN
# Embarked                                       C  ...                   S
#
#                                       882                            883  \
# PassengerId                           883                            884
# Survived                                0                              0
# Pclass                                  3                              2
# Name         Dahlberg, Miss. Gerda Ulrika  Banfield, Mr. Frederick James
# Sex                                female                           male
# Age                                  22.0                           28.0
# SibSp                                   0                              0
# Parch                                   0                              0
# Ticket                               7552               C.A./SOTON 34068
# Fare                              10.5167                           10.5
# Cabin                                 NaN                            NaN
# Embarked                                S                              S
#
#                                 884                                   885  \
# PassengerId                     885                                   886
# Survived                          0                                     0
# Pclass                            3                                     3
# Name         Sutehall, Mr. Henry Jr  Rice, Mrs. William (Margaret Norton)
# Sex                            male                                female
# Age                            25.0                                  39.0
# SibSp                             0                                     0
# Parch                             0                                     5
# Ticket              SOTON/OQ 392076                                382652
# Fare                           7.05                                29.125
# Cabin                           NaN                                   NaN
# Embarked                          S                                     Q
#
#                                886                           887  \
# PassengerId                    887                           888
# Survived                         0                             1
# Pclass                           2                             1
# Name         Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# Sex                           male                        female
# Age                           27.0                          19.0
# SibSp                            0                             0
# Parch                            0                             0
# Ticket                      211536                        112053
# Fare                          13.0                          30.0
# Cabin                          NaN                           B42
# Embarked                         S                             S
#
#                                                   888                    889  \
# PassengerId                                       889                    890
# Survived                                            0                      1
# Pclass                                              3                      1
# Name         Johnston, Miss. Catherine Helen "Carrie"  Behr, Mr. Karl Howell
# Sex                                            female                   male
# Age                                               NaN                   26.0
# SibSp                                               1                      0
# Parch                                               2                      0
# Ticket                                     W./C. 6607                 111369
# Fare                                            23.45                   30.0
# Cabin                                             NaN                   C148
# Embarked                                            S                      C
#
#                              890
# PassengerId                  891
# Survived                       0
# Pclass                         3
# Name         Dooley, Mr. Patrick
# Sex                         male
# Age                         32.0
# SibSp                          0
# Parch                          0
# Ticket                    370376
# Fare                        7.75
# Cabin                        NaN
# Embarked                       Q
#
# [12 rows x 891 columns]
