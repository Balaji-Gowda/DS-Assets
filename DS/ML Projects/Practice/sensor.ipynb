# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel("C:\\Documents\\DS\\TopMentee\\Tableau\\Sources\\prepData.xlsx")
df.head()
# Out:
#              DateTime  Time_Stamp      Time  F1_rHydPump_400Bar  \
# 0 2020-02-10 08:01:00  2020-02-10  08:01:00                 0.2
# 1 2020-02-10 08:06:00  2020-02-10  08:06:00               228.2
# 2 2020-02-10 08:11:00  2020-02-10  08:11:00               228.3
# 3 2020-02-10 08:16:00  2020-02-10  08:16:00               232.3
# 4 2020-02-10 08:21:00  2020-02-10  08:21:00               231.7
#
#    F2_rHydPump_400Bar  F3_rHydPump_400Bar  F4_rHydPump_400Bar  \
# 0               214.0               0.125               216.3
# 1               214.1               0.000               216.8
# 2               203.6               0.125               217.0
# 3               215.2               0.125               216.2
# 4               203.6               0.000               216.3
#
#    F5_rHydPump_400Bar  F6_rHydPump_400Bar  F7_rHydPump_400Bar  ...  \
# 0                 0.2               217.8               223.6  ...
# 1                 0.3               218.0               214.2  ...
# ...

# %%
df.set_index("DateTime",inplace=True)

# %%
df['F1_rHydPump_400Bar'].plot()
# Out:
# <AxesSubplot:xlabel='DateTime'>
