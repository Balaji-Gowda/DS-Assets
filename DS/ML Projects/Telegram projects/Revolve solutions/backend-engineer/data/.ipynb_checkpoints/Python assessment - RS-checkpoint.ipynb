# %%
import pandas as pd

# %%
airlines=pd.read_csv("airlines.csv")
airports=pd.read_csv('airports.csv')
flights=pd.read_csv('flights.csv')
planes=pd.read_csv('planes.csv')

# %%
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %% [markdown]
# ## User story:
# ### We would like to explore and process the flights data in order to answer following questions:
#
# #### 1 how many total number of days does the flights table cover?
#
# #### 2 how many departure cities (not airports) does the flights database cover?
#
# #### 3 what is the relationship between flights and planes tables?
#
# #### 4 which airplane manufacturer incurred the most delays in the analysis period?
#
# #### 5 which are the two most connected cities?

# %%
from datetime import datetime

# %%
type(pd.to_datetime('2022-11-10'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.to_datetime('2022-11-10')
# Out:
# Timestamp('2022-11-10 00:00:00')

# %%
pd.to_datetime(flights[['year','month','day']]).nunique()
# Out:
# 365

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
flights.shape
# Out:
# (336776, 16)

# %% [markdown]
# # 1) 365 days

# %%
l=((flights['year'].map(str)+flights['month'].map(str)+flights['day'].map(str)).unique())

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
(pd.merge(flights,airports,how='left',left_on='origin',right_on='IATA_CODE')).CITY.nunique()
# Out:
# 2

# %% [markdown]
# # 2) 2 cities

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
planes.shape
# Out:
# (3322, 9)

# %%
flights.shape
# Out:
# (336776, 16)

# %%
planes.tailnum.nunique()
# Out:
# 3322

# %%
flights.tailnum.nunique()
# Out:
# 4043

# %% [markdown]
# # 3) 1 - many relationship between planes - flights table

# %%
manf=dict(list(zip(planes.tailnum,planes.manufacturer)))

# %%
flights['manf']=flights.tailnum.map(manf)

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute    manf
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0  BOEING
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0  BOEING
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0  BOEING
# 3     725    JFK  BQN     183.0      1576   5.0    44.0  AIRBUS
# 4     461    LGA  ATL     116.0       762   5.0    54.0  BOEING

# %%
flights['tot_delay']=flights['dep_delay']+flights['arr_delay']
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute    manf  tot_delay
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0  BOEING       13.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0  BOEING       24.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0  BOEING       35.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0  AIRBUS      -19.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0  BOEING      -31.0

# %%
flights.groupby('manf').tot_delay.agg(['sum']).sort_values(by='sum',ascending=False).iloc[0,:]
# Out:
# sum    1947579.0
# Name: EMBRAER, dtype: float64

# %% [markdown]
# # 4) EMBRARER with delay of 1947579 mins

# %%
flights[['origin','dest']].shape
# Out:
# (336776, 2)

# %%
(flights.origin+'_'+flights.dest).value_counts().index[0].split('_')
# Out:
# ['JFK', 'LAX']

# %%
(flights.dest+'_'+flights.origin).value_counts()
# Out:
# LAX_JFK    11262
# ATL_LGA    10263
# ORD_LGA     8857
# SFO_JFK     8204
# CLT_LGA     6168
#            ...
# STL_JFK        1
# LGA_EWR        1
# MEM_JFK        1
# BHM_JFK        1
# LEX_LGA        1
# Length: 224, dtype: int64

# %%
airports[airports['IATA_CODE'].isin(['LAX','JFK'])]
# Out:
#     IATA_CODE                                            AIRPORT         CITY  \
# 166       JFK  John F. Kennedy International Airport (New Yor...     New York
# 176       LAX                  Los Angeles International Airport  Los Angeles
#
#     STATE COUNTRY  LATITUDE  LONGITUDE
# 166    NY     USA  40.63975  -73.77893
# 176    CA     USA  33.94254 -118.40807

# %% [markdown]
# # 5) New York and Los Angeles are most connected cities
