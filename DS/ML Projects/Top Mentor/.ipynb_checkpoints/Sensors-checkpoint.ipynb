# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %%
df=pd.read_excel("Sensor Data Analysis.xlsx")

# %%
df.head()
# Out:
#   Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0 2020-02-10  08:01:00                 0.2               214.0
# 1 2020-02-10  08:06:00               228.2               214.1
# 2 2020-02-10  08:11:00               228.3               203.6
# 3 2020-02-10  08:16:00               232.3               215.2
# 4 2020-02-10  08:21:00               231.7               203.6
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# 3               0.125               216.2                 0.3
# 4               0.000               216.3                 0.1
#
#    F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  ...  \
# 0               217.8               223.6             237.875  ...
# 1               218.0               214.2             237.875  ...
# ...

# %%
pd.pandas.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#   Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0 2020-02-10  08:01:00                 0.2               214.0
# 1 2020-02-10  08:06:00               228.2               214.1
# 2 2020-02-10  08:11:00               228.3               203.6
# 3 2020-02-10  08:16:00               232.3               215.2
# 4 2020-02-10  08:21:00               231.7               203.6
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# 3               0.125               216.2                 0.3
# 4               0.000               216.3                 0.1
#
#    F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  \
# 0               217.8               223.6             237.875
# 1               218.0               214.2             237.875
# ...

# %%
df.head(10)
# Out:
#   Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0 2020-02-10  08:01:00                 0.2               214.0
# 1 2020-02-10  08:06:00               228.2               214.1
# 2 2020-02-10  08:11:00               228.3               203.6
# 3 2020-02-10  08:16:00               232.3               215.2
# 4 2020-02-10  08:21:00               231.7               203.6
# 5 2020-02-10  08:26:00               232.5               209.1
# 6 2020-02-10  08:31:00               231.8               209.1
# 7 2020-02-10  08:36:00                 0.0               204.0
# 8 2020-02-10  08:41:00               231.7               203.5
# 9 2020-02-10  08:46:00               228.3               203.5
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 86 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Time_Stamp             1475 non-null   datetime64[ns]
#  1   Time                   1475 non-null   object
#  2   F1_rHydPump_400Bar     1475 non-null   float64
#  3   F2_rHydPump_400Bar     1475 non-null   float64
#  4   F3_rHydPump_400Bar     1475 non-null   float64
#  5   F4_rHydPump_400Bar     1475 non-null   float64
#  6   F5_rHydPump_400Bar     1475 non-null   float64
#  7   F6_rHydPump_400Bar     1475 non-null   float64
#  8   F7_rHydPump_400Bar     1475 non-null   float64
#  9   F8_rHydPump_400Bar     1475 non-null   float64
#  10  F9_rHydPump_400Bar     1475 non-null   float64
#  11  F10_rHydPump_400Bar    1475 non-null   float64
#  12  F11_rHydPump_400Bar    1475 non-null   float64
#  13  F12_rHydPump_400Bar    1475 non-null   float64
# ...

# %%
df.Time_Stamp.dt.strftime('%Y-%m-%d')
# Out:
# 0       2020-02-10
# 1       2020-02-10
# 2       2020-02-10
# 3       2020-02-10
# 4       2020-02-10
#            ...
# 1470    2020-02-15
# 1471    2020-02-15
# 1472    2020-02-15
# 1473    2020-02-15
# 1474    2020-02-15
# Name: Time_Stamp, Length: 1475, dtype: object

# %%
DT=df["Time_Stamp"].str.cat(df["Time"],sep=' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f8147613b8a0> in <module>
# ----> 1 DT=df["Time_Stamp"].str.cat(df["Time"],sep=' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df2=pd.read_excel("Sensor Data Analysis.xlsx",parse_dates={"DateTime" : ["Time_Stamp","Time"]})

# %%
df2.head()
# Out:
#              DateTime  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0 2020-02-10 08:01:00                 0.2               214.0
# 1 2020-02-10 08:06:00               228.2               214.1
# 2 2020-02-10 08:11:00               228.3               203.6
# 3 2020-02-10 08:16:00               232.3               215.2
# 4 2020-02-10 08:21:00               231.7               203.6
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# 3               0.125               216.2                 0.3
# 4               0.000               216.3                 0.1
#
#    F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  \
# 0               217.8               223.6             237.875
# 1               218.0               214.2             237.875
# ...

# %%
df.set_index("Time_Stamp"+"Time")

# %%
import datetime as dt
DateTime=dt.datetime.combine(dt.date(df["Time_Stamp"]), df["Time"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-326bfda5b268> in <module>
#       1 import datetime as dt
# ----> 2 DateTime=dt.datetime.combine(dt.date(df["Time_Stamp"]), df["Time"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df3
