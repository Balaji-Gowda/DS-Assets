# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("bitcoin_dataset.csv")
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df.shape
# Out:
# (2906, 24)

# %%
list(df.columns)
# Out:
# ['Date',
#  'btc_market_price',
#  'btc_total_bitcoins',
#  'btc_market_cap',
#  'btc_trade_volume',
#  'btc_blocks_size',
#  'btc_avg_block_size',
#  'btc_n_orphaned_blocks',
#  'btc_n_transactions_per_block',
#  'btc_median_confirmation_time',
#  'btc_hash_rate',
#  'btc_difficulty',
#  'btc_miners_revenue',
#  'btc_transaction_fees',
#  'btc_cost_per_transaction_percent',
#  'btc_cost_per_transaction',
#  'btc_n_unique_addresses',
#  'btc_n_transactions',
#  'btc_n_transactions_total',
#  'btc_n_transactions_excluding_popular',
#  'btc_n_transactions_excluding_chains_longer_than_100',
#  'btc_output_volume',
#  'btc_estimated_transaction_volume',
#  'btc_estimated_transaction_volume_usd']

# %%
df.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
mat=df.corr()
mat
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.392474
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868813
# btc_blocks_size                                             0.674507
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.275250
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916937
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806595
# ...

# %%
len(mat.columns)
# Out:
# 23

# %%
def cor_cols(df,thres):
    mat=df.corr()
    cols=set()
#     print(cols)
    for i in range(len(mat.columns)):
        for j in range(i):
            if abs(mat.iloc[i,j])>=thres:
                cols.add(mat.columns[i])                
    return cols

# %%
print(len(list(cor_cols(df,0.2))))
print(df.columns)
# Out:
# 21
# Index(['Date', 'btc_market_price', 'btc_total_bitcoins', 'btc_market_cap',
#        'btc_trade_volume', 'btc_blocks_size', 'btc_avg_block_size',
#        'btc_n_orphaned_blocks', 'btc_n_transactions_per_block',
#        'btc_median_confirmation_time', 'btc_hash_rate', 'btc_difficulty',
#        'btc_miners_revenue', 'btc_transaction_fees',
#        'btc_cost_per_transaction_percent', 'btc_cost_per_transaction',
#        'btc_n_unique_addresses', 'btc_n_transactions',
#        'btc_n_transactions_total', 'btc_n_transactions_excluding_popular',
#        'btc_n_transactions_excluding_chains_longer_than_100',
#        'btc_output_volume', 'btc_estimated_transaction_volume',
#        'btc_estimated_transaction_volume_usd'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 24

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
correlation(df,0.8)
# Out:
# {'btc_avg_block_size',
#  'btc_cost_per_transaction',
#  'btc_difficulty',
#  'btc_estimated_transaction_volume_usd',
#  'btc_hash_rate',
#  'btc_market_cap',
#  'btc_miners_revenue',
#  'btc_n_transactions',
#  'btc_n_transactions_excluding_chains_longer_than_100',
#  'btc_n_transactions_excluding_popular',
#  'btc_n_transactions_per_block',
#  'btc_n_transactions_total',
#  'btc_n_unique_addresses',
#  'btc_trade_volume',
#  'btc_transaction_fees'}

# %%
cols=cor_cols(df,0.8)

# %%
df1=df[cols]

# %%
df1.head()
# Out:
#    btc_n_unique_addresses  btc_market_cap  \
# 0                     241             0.0
# 1                     234             0.0
# 2                     185             0.0
# 3                     224             0.0
# 4                     218             0.0
#
#    btc_n_transactions_excluding_chains_longer_than_100  \
# 0                                                244
# 1                                                235
# 2                                                183
# 3                                                224
# 4                                                218
#
#    btc_n_transactions_excluding_popular  btc_transaction_fees  \
# 0                                   244                   0.0
# 1                                   235                   0.0
# 2                                   183                   0.0
# 3                                   224                   0.0
# 4                                   218                   0.0
#
# ...

# %%
y=df.btc_market_price
y
# Out:
# 0           0.00000
# 1           0.00000
# 2           0.00000
# 3           0.00000
# 4           0.00000
#            ...
# 2901    11524.77667
# 2902    11765.71000
# 2903    11212.65500
# 2904    10184.06167
# 2905    10125.01333
# Name: btc_market_price, Length: 2906, dtype: float64

# %%
df.boxplot("btc_trade_volume",by="btc_market_price")
# Out:
# <AxesSubplot:title={'center':'btc_trade_volume'}, xlabel='btc_market_price'>

# %%
sns.boilkdjs
