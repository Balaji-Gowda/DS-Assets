# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("bitcoin_dataset.csv")
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df.shape
# Out:
# (2906, 24)

# %%
list(df.columns)
# Out:
# ['Date',
#  'btc_market_price',
#  'btc_total_bitcoins',
#  'btc_market_cap',
#  'btc_trade_volume',
#  'btc_blocks_size',
#  'btc_avg_block_size',
#  'btc_n_orphaned_blocks',
#  'btc_n_transactions_per_block',
#  'btc_median_confirmation_time',
#  'btc_hash_rate',
#  'btc_difficulty',
#  'btc_miners_revenue',
#  'btc_transaction_fees',
#  'btc_cost_per_transaction_percent',
#  'btc_cost_per_transaction',
#  'btc_n_unique_addresses',
#  'btc_n_transactions',
#  'btc_n_transactions_total',
#  'btc_n_transactions_excluding_popular',
#  'btc_n_transactions_excluding_chains_longer_than_100',
#  'btc_output_volume',
#  'btc_estimated_transaction_volume',
#  'btc_estimated_transaction_volume_usd']

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                                   0
# btc_market_price                                       0
# btc_total_bitcoins                                     0
# btc_market_cap                                         0
# btc_trade_volume                                       0
# btc_blocks_size                                        0
# btc_avg_block_size                                     0
# btc_n_orphaned_blocks                                  0
# btc_n_transactions_per_block                           0
# btc_median_confirmation_time                           0
# btc_hash_rate                                          0
# btc_difficulty                                         0
# btc_miners_revenue                                     0
# btc_transaction_fees                                   0
# btc_cost_per_transaction_percent                       0
# btc_cost_per_transaction                               0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
mat=df.corr()
mat
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.390385
# btc_market_cap                                              0.999785
# btc_trade_volume                                            0.869779
# btc_blocks_size                                             0.676715
# btc_avg_block_size                                          0.544035
# btc_n_orphaned_blocks                                      -0.077427
# btc_n_transactions_per_block                                0.544690
# btc_median_confirmation_time                                0.275712
# btc_hash_rate                                               0.923315
# btc_difficulty                                              0.918225
# btc_miners_revenue                                          0.987069
# btc_transaction_fees                                        0.810470
# ...

# %%
len(mat.columns)
# Out:
# 23

# %%
def cor_cols(df,thres):
    mat=df.corr()
    cols=set()
#     print(cols)
    for i in range(len(mat.columns)):
        for j in range(i):
            if abs(mat.iloc[i,j])>=thres:
                cols.add(mat.columns[i])                
    return cols

# %%
print(len(list(cor_cols(df,0.2))))
print(df.columns)
# Out:
# 21
# Index(['Date', 'btc_market_price', 'btc_total_bitcoins', 'btc_market_cap',
#        'btc_trade_volume', 'btc_blocks_size', 'btc_avg_block_size',
#        'btc_n_orphaned_blocks', 'btc_n_transactions_per_block',
#        'btc_median_confirmation_time', 'btc_hash_rate', 'btc_difficulty',
#        'btc_miners_revenue', 'btc_transaction_fees',
#        'btc_cost_per_transaction_percent', 'btc_cost_per_transaction',
#        'btc_n_unique_addresses', 'btc_n_transactions',
#        'btc_n_transactions_total', 'btc_n_transactions_excluding_popular',
#        'btc_n_transactions_excluding_chains_longer_than_100',
#        'btc_output_volume', 'btc_estimated_transaction_volume',
#        'btc_estimated_transaction_volume_usd'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 24

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
correlation(df,0.8)
# Out:
# {'btc_avg_block_size',
#  'btc_cost_per_transaction',
#  'btc_difficulty',
#  'btc_estimated_transaction_volume_usd',
#  'btc_hash_rate',
#  'btc_market_cap',
#  'btc_miners_revenue',
#  'btc_n_transactions',
#  'btc_n_transactions_excluding_chains_longer_than_100',
#  'btc_n_transactions_excluding_popular',
#  'btc_n_transactions_per_block',
#  'btc_n_transactions_total',
#  'btc_n_unique_addresses',
#  'btc_trade_volume',
#  'btc_transaction_fees'}

# %%
cols=cor_cols(df,0.8)

# %%
df1=df[cols]

# %%
df1.head()
# Out:
#    btc_n_unique_addresses  btc_market_cap  \
# 0                     241             0.0
# 1                     234             0.0
# 2                     185             0.0
# 3                     224             0.0
# 4                     218             0.0
#
#    btc_n_transactions_excluding_chains_longer_than_100  \
# 0                                                244
# 1                                                235
# 2                                                183
# 3                                                224
# 4                                                218
#
#    btc_n_transactions_excluding_popular  btc_transaction_fees  \
# 0                                   244                   0.0
# 1                                   235                   0.0
# 2                                   183                   0.0
# 3                                   224                   0.0
# 4                                   218                   0.0
#
# ...

# %%
y=pd.DataFrame(df["btc_market_price"])
y
# Out:
#       btc_market_price
# 0              0.00000
# 1              0.00000
# 2              0.00000
# 3              0.00000
# 4              0.00000
# ...                ...
# 2901       11524.77667
# 2902       11765.71000
# 2903       11212.65500
# 2904       10184.06167
# 2905       10125.01333
#
# [2791 rows x 1 columns]

# %%
cols
# Out:
# {'btc_avg_block_size',
#  'btc_cost_per_transaction',
#  'btc_difficulty',
#  'btc_estimated_transaction_volume_usd',
#  'btc_hash_rate',
#  'btc_market_cap',
#  'btc_miners_revenue',
#  'btc_n_transactions',
#  'btc_n_transactions_excluding_chains_longer_than_100',
#  'btc_n_transactions_excluding_popular',
#  'btc_n_transactions_per_block',
#  'btc_n_transactions_total',
#  'btc_n_unique_addresses',
#  'btc_trade_volume',
#  'btc_transaction_fees'}

# %%
# plt.figure(figsize=(15,30))
sns.boxplot(y="btc_cost_per_transaction",data=df)
# Out:
# <AxesSubplot:ylabel='btc_cost_per_transaction'>

# %%
from sklearn.model_selection import train_test_split

# %%
y
# Out:
#       btc_market_price
# 0              0.00000
# 1              0.00000
# 2              0.00000
# 3              0.00000
# 4              0.00000
# ...                ...
# 2901       11524.77667
# 2902       11765.71000
# 2903       11212.65500
# 2904       10184.06167
# 2905       10125.01333
#
# [2791 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(df1,y,test_size=0.3,random_state=1274)

# %%
from sklearn.preprocessing import RobustScaler

# %%
robu=RobustScaler()

# %%
x_train[df1.columns]=robu.fit_transform(x_train)
# Out:
# <ipython-input-131-43d85cddefe3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train[df1.columns]=robu.fit_transform(x_train)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
mod=lin.fit(x_train_scl,y_train)

# %%
mod.score(x_train_scl,y_train)
# Out:
# 0.9999384691886991

# %%
x_test=robu.fit_transform(x_test)

# %%
pred=mod.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# -9.131783520520048e+19
