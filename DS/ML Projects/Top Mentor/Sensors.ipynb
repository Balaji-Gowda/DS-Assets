# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %%
df=pd.read_excel("Sensor Data Analysis.xlsx")

# %%
df.head()
# Out:
#   Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0 2020-02-10  08:01:00                 0.2               214.0
# 1 2020-02-10  08:06:00               228.2               214.1
# 2 2020-02-10  08:11:00               228.3               203.6
# 3 2020-02-10  08:16:00               232.3               215.2
# 4 2020-02-10  08:21:00               231.7               203.6
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# 3               0.125               216.2                 0.3
# 4               0.000               216.3                 0.1
#
#    F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  ...  \
# 0               217.8               223.6             237.875  ...
# 1               218.0               214.2             237.875  ...
# ...

# %%
print(type(df4["DateTime"][0]))
print(type(df["DateTime"][0]))
df4=df2.reset_index()
print(df4.info())
df["DateTime"]=df4.DateTime.to_timestamp
print(df4.info())
print(type(df4["DateTime"][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'method'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 87 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DateTime               1475 non-null   datetime64[ns]
#  1   Time_Stamp             1475 non-null   object
#  2   Time                   1475 non-null   object
#  3   F1_rHydPump_400Bar     1475 non-null   float64
#  4   F2_rHydPump_400Bar     1475 non-null   float64
#  5   F3_rHydPump_400Bar     1475 non-null   float64
#  6   F4_rHydPump_400Bar     1475 non-null   float64
#  7   F5_rHydPump_400Bar     1475 non-null   float64
#  8   F6_rHydPump_400Bar     1475 non-null   float64
#  9   F7_rHydPump_400Bar     1475 non-null   float64
#  10  F8_rHydPump_400Bar     1475 non-null   float64
#  11  F9_rHydPump_400Bar     1475 non-null   float64
#  12  F10_rHydPump_400Bar    1475 non-null   float64
# ...

# %%
pd.pandas.set_option("display.max_columns",None)

# %%
df['Time_Stamp']=df.Time_Stamp.dt.strftime('%Y-%m-%d')

# %%
df.Time.dtypesV
# Out:
# dtype('O')

# %%
type(df['Time'][200])
# Out:
# str

# %%
df["Time"]=df["Time"].astype(str)

# %%
type(df['Time_Stamp'][0])
# Out:
# str

# %%
df["COmbined"]=df['Time_Stamp']+' '+df['Time']

# %%
df.head()
# Out:
#    Time_Stamp      Time  F1_rHydPump_400Bar  F2_rHydPump_400Bar  \
# 0  2020-02-10  08:01:00                 0.2               214.0
# 1  2020-02-10  08:06:00               228.2               214.1
# 2  2020-02-10  08:11:00               228.3               203.6
# 3  2020-02-10  08:16:00               232.3               215.2
# 4  2020-02-10  08:21:00               231.7               203.6
#
#    F3_rHydPump_400Bar  F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# 0               0.125               216.3                 0.2
# 1               0.000               216.8                 0.3
# 2               0.125               217.0                 0.2
# 3               0.125               216.2                 0.3
# 4               0.000               216.3                 0.1
#
#    F6_rHydPump_400Bar  F7_rHydPump_400Bar  F8_rHydPump_400Bar  \
# 0               217.8               223.6             237.875
# 1               218.0               214.2             237.875
# ...

# %%
df.insert(0,"DateTime",df["DT"])

# %%
df.head()
# Out:
#              DateTime  Time_Stamp      Time  F1_rHydPump_400Bar  \
# 0 2020-02-10 08:01:00  2020-02-10  08:01:00                 0.2
# 1 2020-02-10 08:06:00  2020-02-10  08:06:00               228.2
# 2 2020-02-10 08:11:00  2020-02-10  08:11:00               228.3
# 3 2020-02-10 08:16:00  2020-02-10  08:16:00               232.3
# 4 2020-02-10 08:21:00  2020-02-10  08:21:00               231.7
#
#    F2_rHydPump_400Bar  F3_rHydPump_400Bar  F4_rHydPump_400Bar  \
# 0               214.0               0.125               216.3
# 1               214.1               0.000               216.8
# 2               203.6               0.125               217.0
# 3               215.2               0.125               216.2
# 4               203.6               0.000               216.3
#
#    F5_rHydPump_400Bar  F6_rHydPump_400Bar  F7_rHydPump_400Bar  \
# 0                 0.2               217.8               223.6
# 1                 0.3               218.0               214.2
# ...

# %%
df2.drop("DT",axis=1,inplace=True)
df2.set_index("DateTime",inplace=True)
df2.head()
# Out:
#                      Time_Stamp      Time  F1_rHydPump_400Bar  \
# DateTime
# 2020-02-10 08:01:00  2020-02-10  08:01:00                 0.2
# 2020-02-10 08:06:00  2020-02-10  08:06:00               228.2
# 2020-02-10 08:11:00  2020-02-10  08:11:00               228.3
# 2020-02-10 08:16:00  2020-02-10  08:16:00               232.3
# 2020-02-10 08:21:00  2020-02-10  08:21:00               231.7
#
#                      F2_rHydPump_400Bar  F3_rHydPump_400Bar  \
# DateTime
# 2020-02-10 08:01:00               214.0               0.125
# 2020-02-10 08:06:00               214.1               0.000
# 2020-02-10 08:11:00               203.6               0.125
# 2020-02-10 08:16:00               215.2               0.125
# 2020-02-10 08:21:00               203.6               0.000
#
#                      F4_rHydPump_400Bar  F5_rHydPump_400Bar  \
# DateTime
# 2020-02-10 08:01:00               216.3                 0.2
# 2020-02-10 08:06:00               216.8                 0.3
# ...

# %%
df2=df2.reset_index()

# %%
type(df2["DateTime"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
